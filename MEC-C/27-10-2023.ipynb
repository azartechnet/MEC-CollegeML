# %%
import matplotlib.pyplot as plt

# %%
x=[10,20,30,40]
y=[10,20,35,38]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
xaxis=[10,20,30,40]
yaxis=[11,22,33,44]
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(xaxis,yaxis)
plt.grid()
plt.show()

# %%
plt.plot([0,1,2,4])
plt.plot([10,20,30,40])
plt.plot([13,16,19,20])
plt.show()
